# %%
import pandas as pd
import numpy as np
df = pd.read_csv('data_actives.csv')
df.head()
# Out:
#   ﻿companyCode emplStatus         workLocation  costCenter  supvEmplId  \
# 0     Company1     Active  El Dorado Hills, CA         380      1729.0
# 1     Company1     Active           Denver, CO         364      1729.0
# 2     Company1     Active           Denver, CO         364      1729.0
# 3     Company1     Active           Denver, CO         364      1729.0
# 4     Company1     Active           Groton, CT         399      3269.0
#
#                lastHireDate          originalHireDate  \
# 0   Sep 7, 2010 12:00:00 AM   Sep 7, 2010 12:00:00 AM
# 1  Sep 29, 2017 12:00:00 AM  Sep 29, 2017 12:00:00 AM
# 2  Jun 20, 2018 12:00:00 AM  Jun 20, 2018 12:00:00 AM
# 3  Feb 20, 2018 12:00:00 AM  Feb 20, 2018 12:00:00 AM
# 4  Oct 31, 2013 12:00:00 AM  Oct 31, 2013 12:00:00 AM
#
#               seniorityDate flsaType fullPartTime               emplType  \
# 0   Sep 7, 2010 12:00:00 AM   Exempt    Full Time  Contractor/Consultant
# ...
